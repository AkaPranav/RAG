# %% [markdown]
# ### Data Ingenstion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "This is the actuall page content for the current RAG learning!",
    metadata = {
        "source": "RAG learning",
        "pages" : 1,
        "author" : "Akapandey",
        "date_created" : "2026-06-22"
    }
)
doc
# Out:
# Document(metadata={'source': 'RAG learning', 'pages': 1, 'author': 'Akapandey', 'date_created': '2026-06-22'}, page_content='This is the actuall page content for the current RAG learning!')

# %%
## Simple Txt file 

import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt" : """python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. It has a large standard library and a vibrant ecosystem of third-party packages, making it suitable for a wide range of applications, from web development to data science and artificial intelligence."""
}

for filepath,content in sample_text.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
### Textloader

from langchain_community.document_loaders import TextLoader

loader = textLoader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document = loader.load()
document
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. It has a large standard library and a vibrant ecosystem of third-party packages, making it suitable for a wide range of applications, from web development to data science and artificial intelligence.')]

# %%
### Dirrectory loader 

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader, DirectoryLoader

## Load all the 

dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*pdf", ## patterns to match the files 
    loader_cls = PyMuPDFLoader, ## Load class to use 
    show_progress=False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m151 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '../data/pdf/Statement Of Purpose.pdf', 'file_path': '../data/pdf/Statement Of Purpose.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Statement Of Purpose', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Statement Of Purpose(SOP) \n \nMachine Learning has become one of the most impactful technologies of our time, transforming \nthe way data is analyzed and decisions are made. As a Computer Science Engineering \nundergraduate with a CGPA of 8.0, I have developed a strong interest in Machine Learning, \nData Science, and Data Analytics through my academic coursework, projects, and continuous \nself-learning. I am excited about the opportunity to participate in the Amazon ML Summer \nSchool to strengthen my understanding of machine learning fundamentals and learn from \nexperts 
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
